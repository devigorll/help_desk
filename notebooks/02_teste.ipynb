# %%
# Conectando ao banco de dados

import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=localhost;"
    "DATABASE=helpdesk_db;"
    "Trusted_Connection=yes;"
)

cursor = conn.cursor()

# %%
import pandas as pd

# %%
nomes_funcionarios = pd.read_sql()
